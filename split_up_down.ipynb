# %%
import pandas as pd

path = "C:/Users/Jang/passion_people_jupyter/" 
df = pd.read_csv(path+"cluster_temperature.csv",engine="python") 
# print(df.head())

tag_list = []

for i, tag in enumerate((df['tags'])):
    tag = tag[1:-1]
    tag = tag.replace("'","")
    tag = tag.replace(",","")
    tag_list.append(tag.split())
# print(tag_list)
t_list = []
for i, tag in enumerate(tag_list):
    if '하의' in tag:
        t_list.append("1")
    else:
        t_list.append("0")
df["i_tag"] = t_list

# print(df)

#  상의, 하의로 데이터프레임 2개로 나누기
df_down = df[df['i_tag']=='1']
df_up = df[df['i_tag']=='0']
# print(df_down)

del df_down['i_tag']
del df_up['i_tag']
df_down.to_csv('df_down.csv',mode='w',index=False,encoding=' CP949')
df_up.to_csv('df_up.csv',mode='w',index=False,encoding=' CP949')

# %%
# Out:
# 후디 블루 상의 파랑색 심플 캐주얼
# 항공점퍼 블랙 아우터 검정색 심플 캐주얼
# 트랙팬츠 레드 하의 빨간색 스트리트 힙합
# 스커트 체크 하의 체크 심플 캐주얼
# 무톤 블랙 아우터 검정색 심플 캐주얼
# 스커트 체크 하의 체크 걸리시
# 코트 아이보리 아우터 베이지색 스트리트 힙합
# 셔츠 화이트 상의 흰색 걸리시
# 코트 그레이 아우터 회색 심플 캐주얼
# 더플코트 브라운 아우터 갈색 심플 캐주얼
# 코트 브라운 아우터 갈색 심플 캐주얼
# 스커트 블랙 하의 검정색 걸리시
# 베스트 다운 아우터 검정색 스트리트 힙합
# 항공점퍼 블루 아우터 파랑색 심플 캐주얼
# 코트 네이비 아우터 파랑색 걸리시
# 무톤 로맨틱크라운 아우터 갈색 학생 심플 캐주얼
# 라티젠 mustang 아우터 베이지색 학생 걸리시
# 코트 블랙 아우터 검정색 걸리시
# 스커트 레드 하의 빨간색 걸리시
# 무톤 세인트페인 아우터 회색 학생 심플 캐주얼
# 스커트 체크 하의 체크 심플 캐주얼
# 코트 네이비 아우터 파랑색 심플 캐주얼
# 무톤 모던스튜디오 아우터 검정색 모델 스트리트 힙합
# 트랙팬츠 하의 파랑색 스트리트 힙합
# 무톤 프레리 아우터 검정색 전문직 프리랜서 걸리시
# mustang 바이바이섭 아우터 검정색 모델 걸리시
# 패딩 그레이 아우터 회색 섹시 페미닌
# 후디 화이트 아우터 흰색 심플 캐주얼
# 재킷 브라운 아우터 갈색 심플 캐주얼
# 패딩 네이비 아우터 파랑색 스트리트 힙합
# 코트 핑크 아우터 분홍색 심플 캐주얼
# 코트 블랙 아우터 검정색 심플 캐주얼
# 무톤 블랙 아우터 검정색 심플 캐주얼
# 재킷 체크 아우터 체크 심플 캐주얼
# 코트 블랙 아우터 검정색 심플 캐주얼
# 롱 이지비지 베이지 롱코트 아우터 심플 캐주얼
# 팬츠 베이지 하의 베이지색 심플 캐주얼
# 래더재킷 블랙 아우터 검정색 심플 캐주얼
# 재킷 그레이 아우터 회색 섹시 페미닌
# 코트 베이지 아우터 베이지색 심플 캐주얼
# 재킷 블랙 아우터 검정색 애니멀 심플 캐주얼
# ...
