# %%
import pandas as pd

musinsa = pd.read_csv("clustering_style_man.csv")

# %%
category = []
for idx, i in enumerate(musinsa['top_tag']):
    if 'jacket' in i or 'jackets' in i or 'blazer' in i:
        category.append('jacket')
    elif 'mustang' in i:
        category.append('mustang')
    elif 't-shirt' in i or 'sleeve' in i:
        category.append('t-shirt')
    elif 'shirt' in i or 'sweatshirts' in i or 'sweatshirt' in i:
        category.append('shirt')
    elif 'padding' in i:
        category.append('padding')
    elif 'jumper' in i:
        category.append('jumper')
    elif 'cardigan' in i:
        category.append('cardigan')
    elif 'coat' in i or 'court' in i:
        category.append('coat')
    elif 'hood' in i or 'hoody' in i:
        category.append('hoody')
    elif 'knit' in i or 'sweater' in i:
        category.append('knit')
    elif 'blouse' in i:
        category.append('blouse')
    elif 'crop' in i:
        category.append('cropty')
    elif 'bra' in i or 'tank' in i:
        category.append('tanktop')
    else:
        category.append('etc')

musinsa['top_category'] = category
#musinsa[musinsa['top_category'] == 'etc']
#len(musinsa[musinsa['top_category'] == 'etc'])
musinsa = musinsa[musinsa['top_category'] != 'etc']

category = []
for idx, i in enumerate(musinsa['bottom_tag']):
    if 'pants' in i and 'denim' in i:
        category.append('jean')
    elif 'jean' in i or 'denim' in i:
        category.append('jean')
    elif 'slack' in i:
        category.append('slacks')
    elif 'short' in i:
        category.append('shorts')
    elif 'pants' in i or 'pant' in i:
        category.append('pants')
    elif 'skirt' in i:
        category.append('skirt')
    else:
        category.append('etc')

musinsa['bottom_category'] = category

#len(musinsa[musinsa['bottom_category'] == 'etc'])
#musinsa[musinsa['bottom_category'] == 'etc']
musinsa = musinsa[musinsa['bottom_category'] != 'etc']

# %%
color = []
for idx, i in enumerate(musinsa['top_tag']):
    if 'black' in i:
        color.append('black')
    elif 'white' in i:
        color.append('white')
    elif 'blue' in i:
        color.append('blue')
    elif 'green' in i:
        color.append('green')
    elif 'red' in i:
        color.append('red')
    elif 'yellow' in i:
        color.append('yellow')
    elif 'gray' in i or 'silver' in i:
        color.append('gray')
    elif 'navy' in i:
        color.append('navy')
    elif ('beige') in i:
        color.append('beige')
    elif ('pink') in i:
        color.append('pink')
    elif ('kakhi') in i:
        color.append('kakhi')
    elif ('brown') in i:
        color.append('brown')
    elif ('orange') in i:
        color.append('orange')
    elif 'purple' in i:
        color.append('purple')
    elif 'denim' in i:
        color.append('denim')
    elif 'camo' in i:
        color.append('camo')
    elif 'pattern' in i or 'check' in i or 'stripe' in i:
        color.append('pattern')
    else:
        color.append('etc')

musinsa['top_color'] = color

musinsa = musinsa[musinsa['top_color'] != 'etc']
#len(musinsa[musinsa['top_color'] == 'etc'])

# %%
color = []
for idx, i in enumerate(musinsa['bottom_tag']):
    if 'black' in i:
        color.append('black')
    elif 'white' in i:
        color.append('white')
    elif 'blue' in i:
        color.append('blue')
    elif 'green' in i:
        color.append('green')
    elif 'red' in i:
        color.append('red')
    elif 'yellow' in i:
        color.append('yellow')
    elif 'gray' in i or 'silver' in i:
        color.append('gray')
    elif 'navy' in i:
        color.append('navy')
    elif ('beige') in i:
        color.append('beige')
    elif ('pink') in i:
        color.append('pink')
    elif ('kakhi') in i:
        color.append('kakhi')
    elif ('brown') in i:
        color.append('brown')
    elif ('orange') in i:
        color.append('orange')
    elif 'purple' in i:
        color.append('purple')
    elif 'denim' in i:
        color.append('denim')
    elif 'camo' in i:
        color.append('camo')
    elif 'pattern' in i or 'check' in i or 'stripe' in i:
        color.append('pattern')
    else:
        color.append('etc')

musinsa['bottom_color'] = color

musinsa = musinsa[musinsa['bottom_color'] != 'etc']
#len(musinsa[musinsa['bottom_color'] == 'etc'])

# %%
musinsa = musinsa[['dt','style','class','top_img','top_category','top_color','bottom_img','bottom_category','bottom_color']]

# %%
musinsa.to_csv('musinsa_man.csv',mode='w',index=False,encoding='utf-8')
